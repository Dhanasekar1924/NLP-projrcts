# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from PyPDF2 import PdfReader
import numpy as np
import networkx as nx
import spacy
import torch
import random

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def extract_text_from_pdf(file_path):
    text = ""
    with open(file_path, 'rb') as file:
        pdf_reader = PdfReader(file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

# %%
def preprocess_text(text):
    # Tokenize into sentences and words
    sentences = sent_tokenize(text)
    words = [word.lower() for sentence in sentences for word in word_tokenize(sentence)]

    # Remove stopwords and punctuation
    stop_words = set(stopwords.words("english"))
    words = [word for word in words if word.isalpha() and word not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    return words

# %%
def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = set()
    words1 = [w.lower() for w in sent1 if w.lower() not in stopwords]
    words2 = [w.lower() for w in sent2 if w.lower() not in stopwords]
    all_words = list(set(words1 + words2))
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
    for w in words1:
        vector1[all_words.index(w)] = 1
    for w in words2:
        vector2[all_words.index(w)] = 1
    return 1 - cosine_distance(vector1, vector2)

# %%
def build_similarity_matrix(sentences, stop_words):
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i == j:
                continue
            similarity_matrix[i][j] = sentence_similarity(sentences[i], sentences[j], stop_words)
    return similarity_matrix

# %%
def generate_summary(text, top_n=3):
    sentences = sent_tokenize(text)
    stop_words = set(stopwords.words("english"))
    sentence_similarity_matrix = build_similarity_matrix(sentences, stop_words)
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_matrix)
    scores = nx.pagerank(sentence_similarity_graph)
    ranked_sentences = sorted(((scores[i], s) for i, s in enumerate(sentences)), reverse=True)
    summary = " ".join([s for _, s in ranked_sentences[:top_n]])
    return summary

# %%
def perform_ner_spacy(text):
    doc = nlp(text)
    named_entities = [ent.text for ent in doc.ents]
    return named_entities

from transformers import DistilBertTokenizer, DistilBertForQuestionAnswering

# %%
def generate_mcqs_using_distilbert(text, num_options=4):
    tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-cased')
    model = DistilBertForQuestionAnswering.from_pretrained('distilbert-base-cased')

    max_seq_length = tokenizer.model_max_length
    chunks = [text[i:i + max_seq_length - 2] for i in range(0, len(text), max_seq_length - 2)]

    generated_mcqs = []
    for chunk in chunks:
        inputs = tokenizer(chunk, return_tensors="pt", truncation=True, padding=True)
        input_ids = inputs["input_ids"]
        attention_mask = inputs["attention_mask"]

        outputs = model(input_ids, attention_mask=attention_mask)
        answer_start = torch.argmax(outputs.start_logits)
        answer_end = torch.argmax(outputs.end_logits) + 1
        answer = tokenizer.decode(input_ids[0, answer_start:answer_end])

        # Generate options for MCQs
        options = [answer]
        while len(options) < num_options:
            random_option = generate_random_option(text, answer)
            if random_option not in options:
                options.append(random_option)

        # Shuffle the options to avoid any pattern
        random.shuffle(options)

        mcq = {
            "question": "What is " + answer + "?",
            "options": options,
            "answer": options.index(answer)
        }

        generated_mcqs.append(mcq)
    return generated_mcqs

# %%
def generate_random_option(text, correct_answer):
    words = set(word_tokenize(text.lower()))
    words.discard(correct_answer.lower())
    return random.choice(list(words))


num_options_per_question = 4  # Set the number of options per MCQ question
file_path = "C:/Users/Protectt067/OneDrive - PROTECTT AI LABS PVT LTD/python Dhanasekar/internship-assignment-nlp-main/Dataset/chapter_2.pdf"  # Replace with the actual file path
text = extract_text_from_pdf(file_path)
preprocessed_text = preprocess_text(text)
preprocessed_text_str = " ".join(preprocessed_text)  # Convert list of words to a single string
summarized_text = generate_summary(preprocessed_text_str)
generated_mcqs = generate_mcqs_using_distilbert(summarized_text, num_options=num_options_per_question)
# Out:
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print("Generated MCQs:")
for i, mcq in enumerate(generated_mcqs):
    question = mcq['question']
    options = mcq['options']
    answer_index = mcq['answer']
    print(f"{i+1}. {question}")
    for j, option in enumerate(options):
        print(f"   {'ABCD'[j]}. {option}")
    print(f"   Correct Answer: {'ABCD'[answer_index]}")
# Out:
# Generated MCQs:
# 1. What is mughal ruler established control large part territory known india death many mughal governor subadars big zamindars began asserting authority establishing regional kingdom powerful regional kingdom emerged various part india delhi could longer function?
#    A. maulvis
#    B. eloquent
#    C. arm
#    D. mughal ruler established control large part territory known india death many mughal governor subadars big zamindars began asserting authority establishing regional kingdom powerful regional kingdom emerged various part india delhi could longer function
#    Correct Answer: D
# 2. What is ?
#    A. revenue
#    B.
#    C. continuously
#    D. away
#    Correct Answer: B
# 3. What is ##land could compete east india company charter company could venture across ocean looking new land could buy good cheap price carry back europe sell higher price company fear competition english trading company mercantile trading company day made profit primarily excluding competition could buy cheap sell dear royal charter however could prevent european power entering eastern market time first english ship sailed west coast africa round cape good hope crossed indian ocean portugues?
#    A. led
#    B. threatening
#    C. revolt
#    D. ##land could compete east india company charter company could venture across ocean looking new land could buy good cheap price carry back europe sell higher price company fear competition english trading company mercantile trading company day made profit primarily excluding competition could buy cheap sell dear royal charter however could prevent european power entering eastern market time first english ship sailed west coast africa round cape good hope crossed indian ocean portugues
#    Correct Answer: D
# 4. What is ?
#    A.
#    B. mechanical
#    C. direct
#    D. pushed
#    Correct Answer: A
# 5. What is [CLS] ival competitor urge secure market therefore led fierce battle trading company seventeenth eighteenth century regularly sank ship blockaded route prevented rival ship moving supply fig route india eighteenth century mercanti?
#    A. [CLS] ival competitor urge secure market therefore led fierce battle trading company seventeenth eighteenth century regularly sank ship blockaded route prevented rival ship moving supply fig route india eighteenth century mercanti
#    B. africa
#    C. know
#    D. heavy
#    Correct Answer: A
# 6. What is ?
#    A. decide
#    B. true
#    C. injunction
#    D.
#    Correct Answer: D
# 7. What is ?
#    A. accused
#    B.
#    C. greater
#    D. meddling
#    Correct Answer: B
# 8. What is khan followed alivardi khan sirajuddaul?
#    A. course
#    B. daniel
#    C. family
#    D. khan followed alivardi khan sirajuddaul
#    Correct Answer: D
# 9. What is ##ajuddaulah became nawab bengal company worried power keen puppet ruler would willingly?
#    A. image
#    B. ##ajuddaulah became nawab bengal company worried power keen puppet ruler would willingly
#    C. marched
#    D. kolkata
#    Correct Answer: B
# 10. What is ##ajuddaul?
#    A. politics
#    B. made
#    C. put
#    D. ##ajuddaul
#    Correct Answer: D
# 11. What is ?
#    A. living
#    B. worried
#    C. ridiculed
#    D.
#    Correct Answer: D
# 12. What is east india house leadenhall street london picture one meeting progress promise rich territorial ambition mercantile east india company viewed distrust doubt england battle plassey robert clive wrote william pitt one principal secretary state english monarch janu?
#    A. east india house leadenhall street london picture one meeting progress promise rich territorial ambition mercantile east india company viewed distrust doubt england battle plassey robert clive wrote william pitt one principal secretary state english monarch janu
#    B. map
#    C. sandalwood
#    D. holding
#    Correct Answer: A
# 13. What is ?
#    A. piled
#    B. iii
#    C. company
#    D.
#    Correct Answer: D
# 14. What is qasim complained turn defeated battle fought bux?
#    A. build
#    B. higher
#    C. reduced
#    D. qasim complained turn defeated battle fought bux
#    Correct Answer: D
# 15. What is [CLS] l emperor appointed company diwan province bengal diwan?
#    A. matchlock
#    B. [CLS] l emperor appointed company diwan province bengal diwan
#    C. river
#    D. two
#    Correct Answer: B
# 16. What is ?
#    A. close
#    B. explorer
#    C. protested
#    D.
#    Correct Answer: D
# 17. What is ?
#    A. combined
#    B. resource
#    C. maulvis
#    D.
#    Correct Answer: D
# 18. What is ?
#    A. rule
#    B. course
#    C. press
#    D.
#    Correct Answer: D
# 19. What is ?
#    A. interpretation
#    B. amongst
#    C. pleasure
#    D.
#    Correct Answer: D
# 20. What is ##uddaulah awadh son [SEP]?
#    A. ##uddaulah awadh son [SEP]
#    B. holding
#    C. cent
#    D. eleven
#    Correct Answer: A
# 21. What is ?
#    A. resorted
#    B. receiving
#    C.
#    D. feel
#    Correct Answer: C
# 22. What is [CLS] r resident?
#    A. [CLS] r resident
#    B. unchallenged
#    C. yearly
#    D. gaining
#    Correct Answer: A
# 23. What is ?
#    A. long
#    B. presided
#    C. aurangzeb
#    D.
#    Correct Answer: D
# 24. What is sultan killed defending capital seringapatam mysore placed former ruling dynasty wodeyars subsidiary alliance imposed state fig tipu toy tiger picture big mechanical toy tipu possessed see tiger mauling european soldier handle?
#    A. entering
#    B. sultan killed defending capital seringapatam mysore placed former ruling dynasty wodeyars subsidiary alliance imposed state fig tipu toy tiger picture big mechanical toy tipu possessed see tiger mauling european soldier handle
#    C. influence
#    D. zafar
#    Correct Answer: B
# 25. What is ?
#    A.
#    B. else
#    C. instead
#    D. uniformity
#    Correct Answer: A
# 26. What is ##aikwad bhonsle chief held together confederacy peshwa principal minister became effective military administrati [SEP]?
#    A. little
#    B. demand
#    C. ##aikwad bhonsle chief held together confederacy peshwa principal minister became effective military administrati [SEP]
#    D. proceeding
#    Correct Answer: C
# 27. What is [CLS] ve head based pune mahadji sindhia nana phadnis two famous maratha soldier statesman late eighteenth century maratha subdued series war first war ended treaty salbai clear victor second war fought different front resulting british gaining orissa territory north yamuna river including agra delhi finally third war crushed maratha power peshwa removed sent away bithur near kanpur pension company complete control territory south vind?
#    A. [CLS] ve head based pune mahadji sindhia nana phadnis two famous maratha soldier statesman late eighteenth century maratha subdued series war first war ended treaty salbai clear victor second war fought different front resulting british gaining orissa territory north yamuna river including agra delhi finally third war crushed maratha power peshwa removed sent away bithur near kanpur pension company complete control territory south vind
#    B. rarely
#    C. cent
#    D. enter
#    Correct Answer: A
# 28. What is ##annamma took arm led resistance movement arrested died prison rayanna poor chowkidar sangoli kitoor carried resistance popular su [SEP]?
#    A. impeach
#    B. appeal
#    C. ##annamma took arm led resistance movement arrested died prison rayanna poor chowkidar sangoli kitoor carried resistance popular su [SEP]
#    D. several
#    Correct Answer: C
# 29. What is allianceact?
#    A. played
#    B. feel
#    C. allianceact
#    D. well
#    Correct Answer: C
# 30. What is annexed simply applying doctrine satara sambalpur udaipur nagpur jhansi finally company also took [SEP]?
#    A. expense
#    B. sambalpur
#    C. annexed simply applying doctrine satara sambalpur udaipur nagpur jhansi finally company also took [SEP]
#    D. moment
#    Correct Answer: C
# 31. What is awadh time british added argument said obliged duty take awadh order free people mis?
#    A. awadh time british added argument said obliged duty take awadh order free people mis
#    B. intensified
#    C. sangoli
#    D. artist
#    Correct Answer: A
# 32. What is ?
#    A.
#    B. explorer
#    C. handle
#    D. read
#    Correct Answer: A
# 33. What is ?
#    A. held
#    B. deposed
#    C. ruler
#    D.
#    Correct Answer: D
# 34. What is ?
#    A. hope
#    B.
#    C. bce
#    D. western
#    Correct Answer: B
# 35. What is ?
#    A. claimed
#    B. resulting
#    C. decide
#    D.
#    Correct Answer: D
# 36. What is mughals paidal soldier change occurred eighteenth century mughal successor state like awadh benaras?
#    A. mughals paidal soldier change occurred eighteenth century mughal successor state like awadh benaras
#    B. found
#    C. dalhousie
#    D. today
#    Correct Answer: A
# 37. What is ##quent opening speech impeachment warren hastings impeach name people india whose right trodden foot whose country turned desert lastly name human nature name sex name every age name every rank impeach common enemy oppressor impeach common enemy oppressor dharmashastras sans?
#    A. emerge
#    B. commercial
#    C. entering
#    D. ##quent opening speech impeachment warren hastings impeach name people india whose right trodden foot whose country turned desert lastly name human nature name sex name every age name every rank impeach common enemy oppressor impeach common enemy oppressor dharmashastras sans
#    Correct Answer: D
# 38. What is ?
#    A. russia
#    B. court
#    C. politics
#    D.
#    Correct Answer: D
# 39. What is [CLS] epoys read revolt chapter conclusion thus east india company transformed trading company territorial colonial power arrival new steam technology early nineteenth century also aided process till?
#    A. merchant
#    B. house
#    C. [CLS] epoys read revolt chapter conclusion thus east india company transformed trading company territorial colonial power arrival new steam technology early nineteenth century also aided process till
#    D. murshid
#    Correct Answer: C
# 40. What is sultan ruler c dalhousie implemented doctrine maratha kingdom loc [SEP]?
#    A. sultan ruler c dalhousie implemented doctrine maratha kingdom loc [SEP]
#    B. assassinated
#    C. soldier
#    D. produced
#    Correct Answer: A
# 41. What is ?
#    A. whatever
#    B. order
#    C.
#    D. depriving
#    Correct Answer: C
# 42. What is ?
#    A.
#    B. sterling
#    C. crown
#    D. stop
#    Correct Answer: A
# 43. What is [CLS] rationalised [SEP]?
#    A. revolt
#    B. difficult
#    C. [CLS] rationalised [SEP]
#    D. merchant
#    Correct Answer: C
