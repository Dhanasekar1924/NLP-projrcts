# %%
import json
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# %%
# Load the json file
with open('tweets.json') as jfile:
    tweets = json.load(jfile)

# %%
# Convert json to dataframe
df = pd.DataFrame.from_dict(tweets, orient='index')

# %%
df.head(5)
# Out:
#                            tweet_author  \
# 1374140386071961602  Hematopoiesis News
# 1374032432173842437    Michael Wang, MD
# 1373902876553048065         1stOncology
# 1373656782367813635           Toby Eyre
# 1372941634334232586        Lymphoma Hub
#
#                                                             tweet_text
# 1374140386071961602  ⚕️ Scientists conducted a Phase II study of ac...
# 1374032432173842437  This phase 2 Acalabrutinib-Venetoclax (AV) tri...
# 1373902876553048065  #NICE backs #AstraZenecas #Calquence for #CLL ...
# 1373656782367813635  #acalabrutinib is a valuable option in pts int...
# 1372941634334232586  NICE has recommended the use of acalabrutinib ...

# %%
# Define stop words
stop_words = stopwords.words("english")

# %%
stop_words.append("http")

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'http']

# %%
# Define lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Define preprocessing function
def preprocess(tweet):
    # Tokenize the tweet
    tokens = word_tokenize(tweet)
    # Remove stopwords and lemmatize the tokens
    filtered_tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.lower() not in stop_words]
    filtered_text = " ".join(filtered_tokens)
    final = [i for i in filtered_text if i not in string.punctuation]
    final_text = "".join(final)
    return final_text

# %%
df["preprocessed_text"] = df["tweet_text"].apply(preprocess)

# %%
df.head(5)
# Out:
#                            tweet_author  \
# 1374140386071961602  Hematopoiesis News
# 1374032432173842437    Michael Wang, MD
# 1373902876553048065         1stOncology
# 1373656782367813635           Toby Eyre
# 1372941634334232586        Lymphoma Hub
#
#                                                             tweet_text  \
# 1374140386071961602  ⚕️ Scientists conducted a Phase II study of ac...
# 1374032432173842437  This phase 2 Acalabrutinib-Venetoclax (AV) tri...
# 1373902876553048065  #NICE backs #AstraZenecas #Calquence for #CLL ...
# 1373656782367813635  #acalabrutinib is a valuable option in pts int...
# 1372941634334232586  NICE has recommended the use of acalabrutinib ...
#
#                                                      preprocessed_text
# 1374140386071961602  ⚕️ scientist conducted phase ii study acalabru...
# 1374032432173842437  phase 2 acalabrutinibvenetoclax  av  trial sti...
# 1373902876553048065   nice back  astrazenecas  calquence  cll http ...
# 1373656782367813635   acalabrutinib valuable option pt intolerant  ...
# 1372941634334232586  nice recommended use acalabrutinib patient tre...

# %%
l =[]
for i in range(len(df["preprocessed_text"])):
    tokens = word_tokenize(df["preprocessed_text"].iloc[i])
    l.extend(tokens)

# %%
l
# Out:
# ['⚕️',
#  'scientist',
#  'conducted',
#  'phase',
#  'ii',
#  'study',
#  'acalabrutinib',
#  'patient',
#  'relapsedrefractory',
#  'cll',
#  'ibrutinibintolerant',
#  'found',
#  'overall',
#  'response',
#  'rate',
#  '73',
#  'http',
#  'tcoej6m4qpc5p',
#  'http',
#  'tcokuzz6zo47r',
#  'phase',
#  '2',
#  'acalabrutinibvenetoclax',
#  'av',
#  'trial',
#  'still',
#  'recruitment',
#  'phase',
#  'study',
#  'well',
#  'venetoclax',
#  'acalabrutinib',
#  'work',
#  'mcl',
#  'patient',
#  'either',
#  'relapsed',
#  'nonrespondent',
#  'initial',
#  'therapy',
#  'http',
#  'tcogg0g9at23n',
#  'nice',
#  'back',
#  'astrazenecas',
#  'calquence',
#  'cll',
#  'http',
#  'tcovb5lpdogra',
#  'acalabrutinib',
#  'valuable',
#  'option',
#  'pt',
#  'intolerant',
#  'ibrutinib',
#  'valuable',
#  'data',
#  'help',
#  'decision',
#  'making',
#  'cll',
#  'early',
#  'view',
#  'haematologica',
#  'http',
#  'tcoz2kclzax0d',
#  'nice',
#  'recommended',
#  'use',
#  'acalabrutinib',
#  'patient',
#  'treatmentnaïve',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'find',
#  'http',
#  'tco6oujptlcin',
#  'lymsm',
#  'lymphoma',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tcojopnlnid5r',
#  'http',
#  'tco9pwy4nkp4s',
#  'england',
#  'decision',
#  'usually',
#  'come',
#  'wale',
#  'info',
#  'http',
#  'tcosr5tu0zshh',
#  'http',
#  'tcoofdwedlav6',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'acalabrutinib',
#  'chemotherapyfree',
#  'monotherapy',
#  'offered',
#  'patient',
#  'chronic',
#  'lymphocytic',
#  'leukaemia',
#  'oncology',
#  'drugapprovals',
#  'pharma',
#  'healthnews',
#  'find',
#  'http',
#  'tcoqyuft2cn8b',
#  'http',
#  'tcosxve6nggx3',
#  'superstar',
#  'tobyeyre82',
#  'responding',
#  'excellent',
#  'news',
#  'nice',
#  'approval',
#  'acalabrutinib',
#  'frontline',
#  'cll',
#  'fcr',
#  'br',
#  'unsuitable',
#  'patient',
#  'http',
#  'tcolacvpotrwx',
#  'cll',
#  'patient',
#  'know',
#  'drug',
#  'ibrutinib',
#  'yesterday',
#  'uk',
#  'acalabrutinib',
#  'approved',
#  'new',
#  'drug',
#  'pirtobrutinib',
#  'making',
#  'big',
#  'impact',
#  'relapsed',
#  'patient',
#  'recent',
#  'clinicaltrials',
#  'cancertrialsie',
#  'cllsociety',
#  'lalni',
#  'bloodcancerirl',
#  'http',
#  'tcomurr3kphsz',
#  'optimal',
#  'management',
#  'highrisk',
#  'cll',
#  'acalabrutinib',
#  '19',
#  'march',
#  '2021',
#  '700',
#  'pm',
#  '830',
#  'pm',
#  'speaker',
#  '1',
#  'dr',
#  'p',
#  'g',
#  'subramanian',
#  'mumbai',
#  'speaker',
#  '2',
#  'group',
#  'captain',
#  'dr',
#  'harshit',
#  'khurana',
#  'pune',
#  'chair',
#  'dr',
#  'h',
#  'advani',
#  'mumbai',
#  'moderator',
#  'dr',
#  'b',
#  'agarwal',
#  'mumbai',
#  'link',
#  'http',
#  'tcoou2demfice',
#  'http',
#  'tconvaedomrll',
#  'acalabrutinib',
#  'form',
#  'cll',
#  'nice',
#  'todayget',
#  'ready',
#  'swbhpharmacy',
#  'stevenshanu',
#  'hojansenya',
#  'swbhrandd',
#  'oncologyataz',
#  'http',
#  'tcopg1gautz5j',
#  'announced',
#  'today',
#  'thursday',
#  '18th',
#  'march',
#  'national',
#  'institute',
#  'health',
#  'care',
#  'excellence',
#  'nice',
#  'made',
#  'recommendation',
#  'acalabrutinib',
#  'become',
#  'treatment',
#  'option',
#  'certain',
#  'group',
#  'chronic',
#  'lymphocytic',
#  'leukaemia',
#  'cll',
#  'patient',
#  'england',
#  'nice',
#  'recommended',
#  'use',
#  'acalabrutinib',
#  'monotherapy',
#  'option',
#  'adult',
#  '•a',
#  '17p',
#  'deletion',
#  'tp53',
#  'mutation',
#  '•no',
#  '17p',
#  'deletion',
#  'tp53',
#  'mutation',
#  'fludarabine',
#  'plus',
#  'cyclophosphamide',
#  'rituximab',
#  'fcr',
#  'bendamustine',
#  'plus',
#  'rituximab',
#  'br',
#  'unsuitable',
#  'http',
#  'tcontyg8vlkyz',
#  'brand',
#  'new',
#  'oral',
#  'treatment',
#  'acalabrutinib',
#  'taken',
#  'twice',
#  'daily',
#  'tablet',
#  'untreated',
#  'blood',
#  'cancer',
#  'chronic',
#  'lymphocytic',
#  'leukaemia',
#  'today',
#  'thursday',
#  '18',
#  'march',
#  '2021',
#  'recommended',
#  'nh',
#  'use',
#  'nice',
#  'http',
#  'tconloyybepra',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tcop6fy1o0mti',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tcov0wjokqqtm',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tco8raq6sljis',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tcohkpfa0iw6n',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tco6b1ryahrxx',
#  'nice',
#  'back',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'cll',
#  'http',
#  'tcofteaemfsw7',
#  'pharma',
#  'lifesciences',
#  'new',
#  'article',
#  'phase',
#  '2',
#  'study',
#  'acalabrutinib',
#  'ibrutinibintolerant',
#  'patient',
#  'relapsedrefractory',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'http',
#  'tcoosjpzyceze',
#  'cll',
#  'leusm',
#  'hematology',
#  'targeted',
#  'oral',
#  'monotherapy',
#  'calquence',
#  'acalabrutinib',
#  'recommended',
#  'nice',
#  'patient',
#  'chronic',
#  'lymphocytic',
#  'leukaemia',
#  'cll',
#  'http',
#  'tcotj2w5zckd3',
#  'pharmanews',
#  'clinicalresearchnews',
#  'biotechnews',
#  'lifesciencesnews',
#  'medicalnews',
#  'healthcarenews',
#  'pharmiwebnews',
#  'http',
#  'tcowya5uuojqo',
#  'uk',
#  'approve',
#  'new',
#  'treatment',
#  'cll',
#  'acalabrutinib',
#  'available',
#  'ireland',
#  'fall',
#  'far',
#  'behind',
#  'patient',
#  'need',
#  'better',
#  'option',
#  'janrynne',
#  'donnellystephen',
#  'hselive',
#  'davidcullinane',
#  'hsenccp',
#  'paulreiddublin',
#  'ipposi',
#  'paulmcauliffe',
#  'roisinshortall',
#  'http',
#  'tcotw2zainolp',
#  'nicecomms',
#  'back',
#  'nh',
#  'use',
#  'astrazeneca',
#  '’',
#  'calquence',
#  'new',
#  'leukaemia',
#  'indication',
#  'daiichisankyo',
#  '’',
#  'cholesterollowering',
#  'drug',
#  'nilemdo',
#  'nustendi',
#  'heor',
#  'http',
#  'tcopqfk7n9pci',
#  'acalabrutinib',
#  'nicecomms',
#  'approved',
#  '1l',
#  'cll',
#  'uk',
#  'pt',
#  'considered',
#  'unfit',
#  'fcr',
#  'br',
#  'pt',
#  'tp53',
#  'mutdel',
#  'relapsed',
#  'cll',
#  'enjoyed',
#  'talking',
#  'cllsupport',
#  'chair',
#  'trustee',
#  'marc',
#  'auckland',
#  'sky',
#  'news',
#  'great',
#  'news',
#  'cll',
#  'pt',
#  'bloodcanceruk',
#  'http',
#  'tcosh0iidgkel',
#  'safety',
#  'antitumor',
#  'activity',
#  'acalabrutinib',
#  'relapsedrefractory',
#  'bcell',
#  'malignancy',
#  'japanese',
#  'phase',
#  'study',
#  'lymphoma',
#  'lymsm',
#  'http',
#  'tconrxd4yk0zm',
#  'new',
#  'article',
#  'safety',
#  'antitumor',
#  'activity',
#  'acalabrutinib',
#  'relapsedrefractory',
#  'bcell',
#  'malignancy',
#  'japanese',
#  'phase',
#  'study',
#  'http',
#  'tcoivdjs3l0z0',
#  'cll',
#  'leusm',
#  'hematology',
#  'congress',
#  'ebmt21',
#  'michaelwangmd',
#  'mdandersonnews',
#  'discussed',
#  'result',
#  'zuma2',
#  'study',
#  'rr',
#  'mantel',
#  'cell',
#  'lymphoma',
#  'morphology',
#  'prior',
#  'btki',
#  'exposure',
#  'ibrutinib',
#  'andor',
#  'acalabrutinib',
#  'concluded',
#  'subgroup',
#  'drew',
#  'clinical',
#  'benefit',
#  'ktex19',
#  'treatment',
#  'lymsm',
#  'http',
#  'tcovufxrfrbgd',
#  'new2trip',
#  'acalabrutinib',
#  'calquence',
#  'treatment',
#  'chronic',
#  'lymphocytic',
#  'leukaemia',
#  'cll',
#  'http',
#  'tcomr2qszwczx',
#  'calquence',
#  'commercial',
#  'really',
#  'pretty',
#  'lady',
#  'chanel',
#  'twittersupport',
#  'nurse',
#  'think',
#  'new',
#  'clinical',
#  'trial',
#  'acalabrutinib',
#  'umbralisib',
#  'ublituximab',
#  'treatment',
#  'previously',
#  'untreated',
#  'mantle',
#  'cell',
#  'lymphoma',
#  'http',
#  'tcoi42benjlrg',
#  'mcl',
#  'lymsm',
#  'hematology',
#  'solidarity',
#  'negotiated',
#  'astrazeneca',
#  'test',
#  'cancer',
#  'drug',
#  'acalabrutinib',
#  'dampens',
#  'immune',
#  'system',
#  'investigator',
#  'changed',
#  'treatment',
#  'protocol',
#  'include',
#  'medicine',
#  'company',
#  'decided',
#  'give',
#  'green',
#  'light',
#  'http',
#  'tcox65mjlnv42',
#  'icymi',
#  'please',
#  'view',
#  'ash20',
#  'tip',
#  'poster',
#  'presentation',
#  'new',
#  'study',
#  'explore',
#  'combination',
#  'krt232',
#  'mdm2i',
#  'acalabrutinib',
#  'patient',
#  'rr',
#  'bcell',
#  'malignancy',
#  'http',
#  'tcog5uoottdlo',
#  'find',
#  'http',
#  'tcosgbnxj8znx',
#  'lymsm',
#  'cll',
#  'dlbcl',
#  'iqvia',
#  'rds',
#  'argentina',
#  'srl',
#  'representa',
#  'en',
#  'argentina',
#  '1',
#  'janssen',
#  'vaccine',
#  'amp',
#  'prevention',
#  'bv',
#  '2',
#  'pharma',
#  'bv',
#  '3',
#  'astrazeneca',
#  'ab',
#  '4',
#  'amgen',
#  'inc',
#  'acalabrutinib',
#  'apremilast',
#  'lanadelumab',
#  'abataceptremdesivirinfliximabmesilato',
#  'de',
#  'cenicriviroc',
#  'http',
#  'tcokuruk5rkiy',
#  'cc',
#  'spitta1969',
#  'maria',
#  'appreciate',
#  'group',
#  'passed',
#  '4',
#  'fda',
#  'inspection',
#  '2013',
#  'led',
#  'ibrutinib',
#  'fda',
#  'approval',
#  '2017',
#  'led',
#  'acalabrutinib',
#  'fda',
#  'approval',
#  '2020',
#  'led',
#  'brexucarbatagene',
#  'autoleucel',
#  'fda',
#  'approval',
#  'without',
#  'leadership',
#  'wonderful',
#  'team',
#  'possible',
#  'http',
#  'tcofpumj4qaq2',
#  'role',
#  'acalabrutinib',
#  'adult',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'http',
#  'tcoxv81it4zeo',
#  'role',
#  'acalabrutinib',
#  'adult',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'lymphoma',
#  'lymsm',
#  'http',
#  'tcolvp7uro7so',
#  'new',
#  'article',
#  'role',
#  'acalabrutinib',
#  'adult',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'http',
#  'tcoxrlun5evpu',
#  'cll',
#  'leusm',
#  'hematology',
#  'role',
#  'acalabrutinib',
#  'adult',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'http',
#  'tcoapru50bg9r',
#  'new',
#  'article',
#  'role',
#  'acalabrutinib',
#  'adult',
#  'chronic',
#  'lymphocytic',
#  'leukemia',
#  'http',
#  'tcoyanuxmbr89',
#  'cll',
#  'leusm',
#  'hematology',
#  'role',
#  'cd20',
#  'addition',
#  'btk',
#  'inhibitor',
#  'closed',
#  'story',
#  'previously',
#  'published',
#  'obinutuzumab',
#  'benefit',
#  'acalabrutinib',
#  'http',
#  'tcoklsjuwwfdm',
#  'show',
#  'ublituximab',
#  'ibrutinib',
#  'benefit',
#  '17p',
#  'tgtherapeutics',
#  'anthonymatomd',
#  'http',
#  'tcol7qrcv0uds',
#  'new',
#  'clinical',
#  'trial',
#  'acalabrutinib',
#  'rituximab',
#  'treatment',
#  'previously',
#  'untreated',
#  'mantle',
#  'cell',
#  'lymphoma',
#  'http',
#  'tcokpdyk3kvoo',
#  'mcl',
#  'lymsm',
#  'hematology',
#  'acalabrutinib',
#  'alcanza',
#  'el',
#  'objetivo',
#  'primario',
#  'de',
#  'eficacia',
#  'en',
#  'comparación',
#  'con',
#  'ibrutinib',
#  'en',
#  'llc',
#  'astrazenecaes',
#  'http',
#  'tco4vtn1bsx5o',
#  'physician',
#  'view',
#  'preview',
#  'digging',
#  'impressive',
#  'u',
#  'launch',
#  'astrazeneca',
#  's',
#  'calquence',
#  'azn',
#  'http',
#  'tcomv4lvmuuqb',
#  'icymi',
#  'overall',
#  'phase',
#  '3',
#  'elevaterr',
#  'trial',
#  'demonstrated',
#  'efficacy',
#  'acalabrutinib',
#  'safety',
#  'tolerability',
#  'profile',
#  'consistent',
#  'observed',
#  'broader',
#  'acalabrutinib',
#  'clinical',
#  'development',
#  'program',
#  'http',
#  'tcom89j49lbfc',
#  'cll',
#  'research',
#  'acalabrutinib',
#  '–',
#  'analysis',
#  'cardiovascular',
#  'event',
#  'http',
#  'tcospouz0fdnp',
#  'comparing',
#  'acalabrutinib',
#  'standard',
#  'treatment',
#  'patient',
#  'chronic',
#  'lymphocytic',
#  'l',
#  'http',
#  'tcotlxiunst1a',
#  'via',
#  'medivizor',
#  'leukemia',
#  'mcl',
#  'survival',
#  'likely',
#  'affected',
#  'reason',
#  'acalabrutinib',
#  'discontinuation',
#  'http',
#  'tcohsjczh0kq2',
#  'mantle',
#  'cell',
#  'lymphoma',
#  'survival',
#  'likely',
#  'affected',
#  'reason',
#  'acalabrutinib',
#  'discontinuation',
#  'http',
#  'tcocbfjm8ghpy',
#  'http',
#  'tcoplfzmtrpzo',
#  'calquence',
#  'beneficial',
#  'cll',
#  'study',
#  'show',
#  'http',
#  'tcozlyxexhka7',
#  'calquence',
#  'cll',
#  'chroniclymphocyticleukemia',
#  'rarecancer',
#  'treatment',
#  'llsusa',
#  'new',
#  'clinical',
#  'trial',
#  'alicia',
#  'acalabrutinib',
#  'cll',
#  'therapy',
#  'http',
#  'tcoxuhpwiu5mo',
#  'cll',
#  'leusm',
#  'hematology',
#  'http',
#  'tcondvz7ayo0k',
#  'tctm21',
#  'gvhdsm',
#  'chronicgvhd',
#  'stephanieleemd',
#  'number',
#  'registered',
#  'study',
#  'cgvhd',
#  'drug',
#  'study',
#  'newer',
#  'itinib',
#  'oral',
#  'acalabrutinib',
#  'http',
#  'tcocxlx3uwecv',
#  'mantle',
#  'cell',
#  'lymphoma',
#  'treatment',
#  'market',
#  'product',
#  'type',
#  'acalabrutinib',
#  'jcar017',
#  'endusersapplication',
#  'hospital',
#  'clinic',
#  'market',
#  'share',
#  'forecast',
#  'data',
#  'indepth',
#  'analysis',
#  'detailed',
#  'overview',
#  'forecast',
#  '2021',
#  '–',
#  '2028',
#  'http',
#  'tcoh3s3og3g7n',
#  'review',
#  'tried',
#  'situate',
#  'acalabrutinib',
#  'among',
#  'treatment',
#  'option',
#  'patient',
#  'treatmentnaive',
#  'relref',
#  'cll',
#  'http',
#  'tcoajnffcevep',
#  'acalabrutinib',
#  'calquence®',
#  'hta',
#  'id',
#  '20063',
#  'national',
#  'centre',
#  'pharmacoeconomics',
#  'http',
#  'tcohvplp5ze5b',
#  'http',
#  'tcowi0dvbzxzt',
#  'news',
#  'von',
#  'http',
#  'tcoy3rvlbthwz',
#  '–',
#  'lesen',
#  'sie',
#  'jetzt',
#  'den',
#  'vollständigen',
#  'beitrag',
#  'unter',
#  'http',
#  'tcoc0mrjsbxlu',
#  'arzt',
#  'schmerz',
#  'cllimmunchemotherapie',
#  'leukämie',
#  'immuntherapie',
#  'neutropenie',
#  'mutation',
#  'acalabrutinib',
#  'patient',
#  'therapie',
#  'unverträglichkeiten',
#  'zulassung',
#  'studie',
#  'video',
#  'dr',
#  'danilov',
#  'ohsunews',
#  'discus',
#  'use',
#  'acalabrutinib',
#  'calquencehcp',
#  'treatment',
#  'option',
#  'patient',
#  'cll',
#  'sll',
#  'mcl',
#  'watch',
#  'http',
#  'tcouulj3g798s',
#  'meded',
#  'medtwitter',
#  'healthcare',
#  'http',
#  'tco0fhgk0h1v1',
#  'video',
#  'interview',
#  ...]

# %%
entities_freq = pd.Series(l).value_counts()

# %%
entities_freq
# Out:
# http             46995
# cll              28689
# leukemia         19786
# lymphocytic      17378
# chronic          17101
#                  ...
# tcofawzr5yh0o        1
# tcollbkijo8un        1
# gallon               1
# tcorlwuh8wznu        1
# tcoihcjylt0xv        1
# Length: 85374, dtype: int64

# %%
a = pd.Series(entities_freq)
b = a.reset_index()
b = b.rename({"index":"entities",0:"frequency"},axis=1)
b.sort_values("frequency",ascending=False,inplace=True)
b.reset_index(drop=True,inplace=True)

# %%
b
# Out:
#             entities  frequency
# 0               http      46995
# 1                cll      28689
# 2           leukemia      19786
# 3        lymphocytic      17378
# 4            chronic      17101
# ...              ...        ...
# 85369  tcoqjnqs3nhhp          1
# 85370  tcod36vvtvs3y          1
# 85371  tcolpl9ln9iqn          1
# 85372  tcotjsye55rt1          1
# 85373  tcoihcjylt0xv          1
#
# [85374 rows x 2 columns]

# %%
import numpy as np

# %%
b1 = b[b["frequency"]>100]

# %%
b1
# Out:
#          entities  frequency
# 0            http      46995
# 1             cll      28689
# 2        leukemia      19786
# 3     lymphocytic      17378
# 4         chronic      17101
# ..            ...        ...
# 823    specialist        102
# 824  prescription        101
# 825           los        101
# 826     caregiver        101
# 827        really        101
#
# [828 rows x 2 columns]

# %%
b1.to_csv("objective1.csv")

# %%
max_freq_words = b1["entities"].values

# %%
max_freq = max_freq_words.tolist()

# %%
max_freq
# Out:
# ['http',
#  'cll',
#  'leukemia',
#  'lymphocytic',
#  'chronic',
#  'patient',
#  'treatment',
#  'new',
#  'cancer',
#  'lymphoma',
#  'leusm',
#  'amp',
#  'ibrutinib',
#  'acalabrutinib',
#  'cell',
#  'dr',
#  'therapy',
#  'trial',
#  'calquence',
#  'venetoclax',
#  'study',
#  's',
#  'drug',
#  'hematology',
#  '’',
#  'fda',
#  'clinical',
#  'relapsed',
#  'article',
#  'phase',
#  'via',
#  'data',
#  'lymsm',
#  'astrazeneca',
#  'w',
#  'expert',
#  'research',
#  'inhibitor',
#  'covid19',
#  'learn',
#  'video',
#  'combination',
#  'leukaemia',
#  'adult',
#  'cllsm',
#  'result',
#  'blood',
#  'rituximab',
#  'discus',
#  'disease',
#  'oncology',
#  'u',
#  'btk',
#  'today',
#  'option',
#  'de',
#  'response',
#  'show',
#  'review',
#  'mantle',
#  'news',
#  'md',
#  'bcell',
#  'obinutuzumab',
#  'get',
#  'plus',
#  'may',
#  '3',
#  'refractory',
#  'relapsedrefractory',
#  'survival',
#  'watch',
#  'approves',
#  'risk',
#  'year',
#  'targeted',
#  'pt',
#  'approved',
#  'mutation',
#  'see',
#  'medivizor',
#  'novel',
#  'outcome',
#  'bloodcancer',
#  'help',
#  '2',
#  'treated',
#  'read',
#  'great',
#  'approval',
#  'live',
#  'update',
#  'report',
#  'gt',
#  'mdandersonnews',
#  'latest',
#  'small',
#  'share',
#  'one',
#  'la',
#  'available',
#  'care',
#  'efficacy',
#  'previously',
#  'untreated',
#  'health',
#  'case',
#  'clinicaltrial',
#  'join',
#  'day',
#  'time',
#  'need',
#  'abbvie',
#  'analysis',
#  'effective',
#  'en',
#  'lymphocyte',
#  'diagnosed',
#  'treat',
#  'imbruvica',
#  'patientpower',
#  'placebo',
#  'people',
#  'check',
#  'акалабрутиниб',
#  'highrisk',
#  'early',
#  'ash18',
#  'аналог',
#  'описание',
#  'first',
#  'показа',
#  'luciacalabru',
#  'калквенс',
#  'therapeutic',
#  '“',
#  'potential',
#  'vs',
#  'frontline',
#  'market',
#  'v',
#  'leukemiamda',
#  'use',
#  'cllpy',
#  'diagnosis',
#  'unidasporelobjetivo',
#  'sll',
#  'meeting',
#  '”',
#  'mcl',
#  'work',
#  'mrd',
#  'role',
#  'group',
#  '⏱️',
#  'agent',
#  'high',
#  'rate',
#  'benefit',
#  'looking',
#  'safety',
#  '🔴⚪⚫',
#  'know',
#  'prognostic',
#  'type',
#  'impact',
#  'treating',
#  '1',
#  'enrolling',
#  'rr',
#  'important',
#  'us',
#  'find',
#  'et',
#  '\u2066',
#  'chroniclymphocyticleukemia',
#  'register',
#  'idelalisib',
#  'longterm',
#  'car',
#  'pfs',
#  'iii',
#  'announces',
#  'growing',
#  'nonhodgkin',
#  'medicine',
#  'advance',
#  'effect',
#  'b',
#  'involving',
#  'ash19',
#  'support',
#  'common',
#  'slow',
#  'progression',
#  'activity',
#  'combo',
#  'ash20',
#  'primarily',
#  'please',
#  'firstline',
#  'presented',
#  'ashhematology',
#  'good',
#  'malignancy',
#  'global',
#  'free',
#  '⚽',
#  'question',
#  'resistance',
#  'rt',
#  'tcell',
#  'current',
#  'gene',
#  'tcoa7uh6eqlyn',
#  'next',
#  'life',
#  'john',
#  'session',
#  '–',
#  'pharma',
#  'nt',
#  'talk',
#  'anthonymatomd',
#  'chemoimmunotherapy',
#  'roche',
#  'venclexta',
#  'breakthrough',
#  'story',
#  'best',
#  'cart',
#  'al',
#  'aml',
#  'event',
#  'azn',
#  'designation',
#  'el',
#  'management',
#  'oral',
#  'hemonc',
#  'associated',
#  'living',
#  'like',
#  'hear',
#  'experience',
#  'bcl2',
#  'test',
#  'immunotherapy',
#  'expression',
#  'interview',
#  'light',
#  'danafarber',
#  'many',
#  'week',
#  'ash',
#  'kinase',
#  'immune',
#  'society',
#  'landscape',
#  'could',
#  'le',
#  'come',
#  'remission',
#  'forward',
#  'webinar',
#  'acute',
#  'strategy',
#  'myeloma',
#  '2020',
#  'positive',
#  'vjhemonc',
#  'regimen',
#  'receptor',
#  'genetic',
#  'chemotherapy',
#  'well',
#  'present',
#  'ash17',
#  'approach',
#  'infection',
#  'status',
#  'area',
#  'development',
#  'oncoalert',
#  'take',
#  'green',
#  'insight',
#  'factor',
#  'testing',
#  'line',
#  'future',
#  'thanks',
#  'month',
#  'team',
#  'older',
#  'coronavirus',
#  'used',
#  'nhl',
#  'leukemiasmall',
#  'say',
#  'international',
#  'richter',
#  '4',
#  '17p',
#  'sequencing',
#  'iwcll',
#  'part',
#  'community',
#  'ofatumumab',
#  'primary',
#  'key',
#  'cello',
#  'better',
#  'rx',
#  'researcher',
#  'presentation',
#  'using',
#  'eu',
#  'standard',
#  'tgtx',
#  'challenge',
#  'two',
#  'prior',
#  'still',
#  'published',
#  'antibody',
#  'residual',
#  '2017',
#  '2019',
#  'tumor',
#  'deletion',
#  'conference',
#  'evaluating',
#  'including',
#  '5',
#  'sharman',
#  'prof',
#  'followup',
#  'look',
#  'promising',
#  'con',
#  'start',
#  'recent',
#  'multiple',
#  '12',
#  '2018',
#  'duvelisib',
#  'haematology',
#  'ash15',
#  'promise',
#  'imbruvica®',
#  'columbiamed',
#  'ii',
#  'nejm',
#  'endcancer',
#  'marrow',
#  'bendamustine',
#  'highlight',
#  'doctor',
#  'center',
#  'transformation',
#  'profile',
#  'program',
#  'cure',
#  '10',
#  'uk',
#  'online',
#  '…',
#  'make',
#  'updated',
#  'finding',
#  'cllsociety',
#  'perspective',
#  'jennifer',
#  'give',
#  'chemo',
#  'minimal',
#  'jeff',
#  're',
#  'access',
#  'targeting',
#  'kind',
#  'discussion',
#  'asco',
#  'del',
#  'lamanna',
#  'cme',
#  'symptom',
#  'another',
#  'powerful',
#  'information',
#  'qualify',
#  'post',
#  'medical',
#  'abbv',
#  'ublituximab',
#  'change',
#  'improves',
#  '2016',
#  'signaling',
#  'found',
#  'also',
#  'model',
#  'que',
#  'target',
#  'listen',
#  'fcr',
#  'pipeline',
#  'way',
#  'abstract',
#  'monotherapy',
#  'improved',
#  'granted',
#  'suggest',
#  'link',
#  'onclive',
#  'cml',
#  'virtual',
#  'bloodjournal',
#  'tyrosine',
#  'showed',
#  'grant',
#  'plc',
#  'bruton',
#  'exciting',
#  'resource',
#  '🏆',
#  'bone',
#  'sloankettering',
#  'panel',
#  'usfda',
#  'chlorambucil',
#  'evolution',
#  'phd',
#  'tp53',
#  'last',
#  'thank',
#  'umbralisib',
#  'world',
#  'miss',
#  'without',
#  'prognosis',
#  'side',
#  'interesting',
#  'explains',
#  'llsusa',
#  'paper',
#  'mmsm',
#  'sign',
#  'knowledgeisbestrx',
#  'based',
#  'wwierda',
#  'meet',
#  'top',
#  'family',
#  'molecular',
#  'ok',
#  'big',
#  'severe',
#  'toxicity',
#  'final',
#  'actively',
#  'want',
#  'journal',
#  'received',
#  'progressionfree',
#  'practice',
#  'pm',
#  'myeloid',
#  'era',
#  'american',
#  'm',
#  'company',
#  'clinicaltrials',
#  'bloodcancerawareness',
#  'go',
#  'full',
#  'nice',
#  'cost',
#  'follicular',
#  'initial',
#  'para',
#  'furman',
#  'form',
#  'ash16',
#  'specific',
#  'improve',
#  'info',
#  'member',
#  'hope',
#  'dlbcl',
#  'j',
#  'wierda',
#  'system',
#  'st',
#  '6',
#  'growth',
#  'would',
#  'andrewschorr',
#  'course',
#  'annual',
#  'wait',
#  'overall',
#  'leucemia',
#  'susan',
#  'newly',
#  'back',
#  'endpoint',
#  'syndrome',
#  'transplant',
#  'friend',
#  'compared',
#  'project',
#  'e',
#  'overview',
#  'setting',
#  'blog',
#  'shot',
#  'safe',
#  'long',
#  'combined',
#  'cllsll',
#  'science',
#  'among',
#  'pathway',
#  'receives',
#  'complete',
#  'different',
#  'level',
#  'drmdavids',
#  'weillcornell',
#  'monoclonal',
#  'elderly',
#  'second',
#  'existing',
#  'healthcare',
#  'coming',
#  'keating',
#  'death',
#  'condition',
#  'improvement',
#  'iwcll2017',
#  'versus',
#  'inhibition',
#  'zanubrutinib',
#  'un',
#  'working',
#  'tomorrow',
#  'lenalidomide',
#  'allogeneic',
#  'unicologne',
#  'osucccjames',
#  'woyach',
#  'issue',
#  'application',
#  'stage',
#  'advocate',
#  'stem',
#  'win',
#  'priority',
#  'age',
#  'chromosomal',
#  'murano',
#  'genomic',
#  'follow',
#  'cancerresearch',
#  'brown',
#  'opportunity',
#  'active',
#  'human',
#  'dose',
#  'abnormality',
#  'lead',
#  '1st',
#  'open',
#  'q',
#  'power4patients',
#  'ehahematology',
#  'ighv',
#  'visit',
#  'according',
#  'ask',
#  'tolerability',
#  'advice',
#  'az',
#  'randomized',
#  'leading',
#  'transplantation',
#  '2015',
#  'dna',
#  'taking',
#  'poster',
#  'excellent',
#  'summary',
#  'move',
#  'higher',
#  'love',
#  'durable',
#  'breaking',
#  'protein',
#  'guideline',
#  'scan',
#  'pattern',
#  'rare',
#  'right',
#  'least',
#  'european',
#  'vaccine',
#  'sun',
#  'linked',
#  'treatmentnaïve',
#  'following',
#  'torneoclausura',
#  'david',
#  'learning',
#  'answer',
#  'alone',
#  'marker',
#  'workshop',
#  'powerfulin2016',
#  'significantly',
#  'presenting',
#  'orphan',
#  'por',
#  'network',
#  'date',
#  'aim',
#  'genentech',
#  'antigen',
#  'indication',
#  'tcow83aqpuk5a',
#  'number',
#  'drs',
#  'leukaemiacareuk',
#  'lt',
#  'pharmaceutical',
#  'click',
#  'r',
#  'hodgkin',
#  'p',
#  'function',
#  'hemeonc',
#  'michael',
#  'managing',
#  'hillmen',
#  'evidence',
#  'three',
#  '📌',
#  'lymphomahub',
#  'survivor',
#  'chemotherapyfree',
#  'much',
#  'affect',
#  'related',
#  'mabtherea',
#  'detail',
#  'maintenance',
#  'regulatory',
#  'canada',
#  'tg',
#  'excited',
#  'medication',
#  'decision',
#  'pivotal',
#  'colleague',
#  'awareness',
#  'partner',
#  '30',
#  'adverse',
#  'association',
#  'melanoma',
#  'increased',
#  'others',
#  'gribben',
#  'relapse',
#  'realworld',
#  'mpn',
#  'emerging',
#  'morning',
#  'state',
#  'aggressive',
#  'focus',
#  'roundup',
#  'town',
#  'thought',
#  'o',
#  'discussing',
#  '‘',
#  'due',
#  'solution',
#  'gazyva',
#  'publication',
#  'met',
#  'recommended',
#  '00',
#  'stay',
#  'pi3k',
#  'single',
#  'recently',
#  '8',
#  'cause',
#  'discussed',
#  'microenvironment',
#  '9',
#  'advanced',
#  'participate',
#  'led',
#  'mechanism',
#  'price',
#  'manage',
#  'education',
#  'launch',
#  'increase',
#  'duration',
#  'yet',
#  'fludarabine',
#  'series',
#  'icymi',
#  '14',
#  'nicole',
#  'pickup',
#  'importance',
#  'paralysis',
#  'charity',
#  'ctsm',
#  'ad',
#  'fecha',
#  'lymphocytosis',
#  'tconyhgvhpqve',
#  'understanding',
#  'collaboration',
#  'feature',
#  'superior',
#  'implication',
#  'jeffsharman',
#  'pubmed',
#  'c',
#  'value',
#  'going',
#  'biotech',
#  'covid',
#  'low',
#  'made',
#  'hcsm',
#  'receiving',
#  'pacientes',
#  'contact',
#  'large',
#  'assessment',
#  'reveals',
#  'trend',
#  'petermaccc',
#  'l',
#  'journey',
#  '20',
#  'btki',
#  '—',
#  'clonal',
#  'across',
#  '15',
#  'sharing',
#  'identify',
#  'reduced',
#  'med',
#  'demonstrated',
#  'provides',
#  'immunoonc',
#  'treatmentnaive',
#  'se',
#  'difference',
#  'comparing',
#  'explores',
#  '7',
#  'soon',
#  'getting',
#  'thing',
#  'control',
#  'got',
#  'view',
#  'offer',
#  'peter',
#  'progress',
#  'tell',
#  'march',
#  'regarding',
#  'cllireland',
#  'orr',
#  'changing',
#  'verastem',
#  'consider',
#  'brian',
#  'hematologic',
#  'book',
#  'asco19',
#  'eichhorst',
#  'william',
#  '1l',
#  'combining',
#  'mean',
#  'bcells',
#  'think',
#  'several',
#  'richard',
#  'fatigue',
#  'stop',
#  'bloodcancerawarenessmonth',
#  'recommendation',
#  'eha24',
#  'thompson',
#  'generation',
#  'starting',
#  'tumorimmuno',
#  'tune',
#  'let',
#  'significant',
#  'medium',
#  'said',
#  'acp196',
#  'step',
#  'understand',
#  '11',
#  'multiplemyeloma',
#  'meded',
#  'specialist',
#  'prescription',
#  'los',
#  'caregiver',
#  'really']

# %%
def second_preprocess(tweet):
    # Tokenize the tweet
    tokens = word_tokenize(tweet)
    # Remove stopwords and lemmatize the tokens
    filtered_tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens if (token.lower() not in stop_words) and (token.lower()in max_freq)]
    filtered_text = " ".join(filtered_tokens)
    final = [i for i in filtered_text if i not in string.punctuation]
    final_text = "".join(final)
    return final_text

# %%
df["final_preprocess"] = df["tweet_text"].apply(second_preprocess)

# %%
df["final_preprocess"]
# Out:
# 1374140386071961602    phase ii study acalabrutinib cll found overall...
# 1374032432173842437    phase 2 trial still phase study well venetocla...
# 1373902876553048065                                   nice calquence cll
# 1373656782367813635    acalabrutinib option ibrutinib data help decis...
# 1372941634334232586    nice recommended use acalabrutinib chronic lym...
#                                              ...
# 551103473643945985                                                   cll
# 551102786675290112                                                   cll
# 550969541186953217                                        idelalisib cll
# 550941480525635584       expression outcome chronic lymphocytic leukemia
# 550579446537678849         pathway identify chronic lymphocytic leukemia
# Name: final_preprocess, Length: 43347, dtype: object

# %%
df.to_csv("before_result.csv")

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
df['final_preprocess_tokens'] = df['final_preprocess'].apply(lambda x: x.split())

# %%
df1=df[['tweet_author']]

# %%
#df1 = df1.explode('final_preprocess_tokens')

# %%
df1
# Out:
#                            tweet_author
# 1374140386071961602  Hematopoiesis News
# 1374032432173842437    Michael Wang, MD
# 1373902876553048065         1stOncology
# 1373656782367813635           Toby Eyre
# 1372941634334232586        Lymphoma Hub
# ...                                 ...
# 551103473643945985   Joy is a Lifestyle
# 551102786675290112        𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 550969541186953217                IQWiG
# 550941480525635584            Medibooks
# 550579446537678849            Medibooks
#
# [43347 rows x 1 columns]

# %%
from nltk.util import ngrams

# %%
def extract_ngrams(x):
    tokens = word_tokenize(x)
    n = 2  # set the value of n for the n-grams
    bigrams = ngrams(tokens, n)
    return list(bigrams)

# %%
df1["result"] = df["final_preprocess"].apply(extract_ngrams)
# Out:
# <ipython-input-37-b2b64963fb0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["result"] = df["final_preprocess"].apply(extract_ngrams)

# %%
df1=df1.explode("result")

# %%
print(df1['result'].dtype)
# Out:
# object

# %%
df1
# Out:
#                            tweet_author                   result
# 1374140386071961602  Hematopoiesis News              (phase, ii)
# 1374140386071961602  Hematopoiesis News              (ii, study)
# 1374140386071961602  Hematopoiesis News   (study, acalabrutinib)
# 1374140386071961602  Hematopoiesis News     (acalabrutinib, cll)
# 1374140386071961602  Hematopoiesis News             (cll, found)
# ...                                 ...                      ...
# 550941480525635584            Medibooks  (lymphocytic, leukemia)
# 550579446537678849            Medibooks      (pathway, identify)
# 550579446537678849            Medibooks      (identify, chronic)
# 550579446537678849            Medibooks   (chronic, lymphocytic)
# 550579446537678849            Medibooks  (lymphocytic, leukemia)
#
# [297246 rows x 2 columns]

# %%
from textblob import TextBlob

# Define a function to get the sentiment
def get_sentiment(tweet):
    return TextBlob(tweet).sentiment.polarity

# %%
#Check for NaN values
print(df1["result"].isnull().sum())

#drop NaN values
df1 = df1.dropna(subset=["result"])

#Convert the column to string
df1["result"] = df1["result"].astype(str)

#Apply the function to get the sentiment
df1["sentiment"] = df1["result"].apply(get_sentiment)
# Out:
# 1445
# <ipython-input-42-3e66d34799c0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["result"] = df1["result"].astype(str)
# <ipython-input-42-3e66d34799c0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["sentiment"] = df1["result"].apply(get_sentiment)

# %%
df1["sentiment"] = df1["sentiment"].apply(lambda x: "positive" if x > 0 else "negative" if x < 0 else "neutral")
# Out:
# <ipython-input-43-ce2367f6764c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["sentiment"] = df1["sentiment"].apply(lambda x: "positive" if x > 0 else "negative" if x < 0 else "neutral")

# %%
df1
# Out:
#                            tweet_author                       result sentiment
# 1374140386071961602  Hematopoiesis News              ('phase', 'ii')   neutral
# 1374140386071961602  Hematopoiesis News              ('ii', 'study')   neutral
# 1374140386071961602  Hematopoiesis News   ('study', 'acalabrutinib')   neutral
# 1374140386071961602  Hematopoiesis News     ('acalabrutinib', 'cll')   neutral
# 1374140386071961602  Hematopoiesis News             ('cll', 'found')   neutral
# ...                                 ...                          ...       ...
# 550941480525635584            Medibooks  ('lymphocytic', 'leukemia')   neutral
# 550579446537678849            Medibooks      ('pathway', 'identify')   neutral
# 550579446537678849            Medibooks      ('identify', 'chronic')   neutral
# 550579446537678849            Medibooks   ('chronic', 'lymphocytic')   neutral
# 550579446537678849            Medibooks  ('lymphocytic', 'leukemia')   neutral
#
# [295801 rows x 3 columns]

# %%
# Save the results to a csv file
df1[["result","tweet_author","sentiment"]].to_csv("objective2.csv", index=False)
